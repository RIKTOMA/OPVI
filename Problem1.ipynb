# %%
import numpy as np
from functions_exp1 import tabelle as tables
from functions_exp1 import pytolatex

# %%
#seed=np.random.randint(100000)
seed=60776
iters=10
sets=["cubo","sfera","simplesso"]

# %%
#parameters for tab1
n=50
l=10
L=20

eps=0.01
rho=1
sigma=1.2


tabs={}
for j in range(3):
    parametri={}
    for i in range(4):
        
        parametri[i]=[n,l,L,sets[j],iters,eps,rho,sigma,i*5]
    tabs[j]=tables(parametri,seed)

for j in range(3):
    print(pytolatex(np.round(tabs[j],4)))
# Out:
# &0.5257&19.9&38.1885&11.0&0.0102&6.3246&0.0016\\
# &2.0247&22.0&64.8016&41.6&0.0931&6.3246&0.0147\\
# &4.6364&25.1&111.1694&107.4&0.4684&6.3246&0.0741\\
# &7.2937&26.9&155.7424&154.0&0.6285&6.3246&0.0994\\
# &
# &0.3265&32.5&376.0041&12.9&0.0245&1.7889&0.0137\\
# &0.3152&32.5&376.0041&11.6&0.0232&1.7889&0.013\\
# &0.2972&32.4&370.307&10.0&0.0207&1.7889&0.0116\\
# &0.2728&32.3&363.4706&8.2&0.0181&1.7889&0.0101\\
# &
# &0.1005&17.4&27.0748&3.4&0.0102&1.2649&0.0081\\
# &0.1734&20.8&83.8873&10.0&0.0516&1.2649&0.0408\\
# &1.068&25.0&160.3226&77.7&0.3045&1.2649&0.2407\\
# &0.8267&29.1&206.9394&56.6&0.3778&1.2649&0.2986\\
# &

# %%
#parameters for tab 2
n=50
l=10
b=np.sqrt(150)
L=[20,50,100]

eps=0.01
rho=1
sigma=1.2

tabs={}
for j in range(3):
    parametri={}
    for i in range(3):
        
        parametri[i]=[n,l,L[i],sets[j],iters,eps,rho,sigma,b]
    tabs[j]=tables(parametri,seed)

for j in range(3):
    print(pytolatex(np.round(tabs[j],4)))
# Out:
# &4.636&25.7&121.6324&110.6&0.5759&6.3246&0.0911\\
# &14.3861&22.4&71.3144&258.7&0.912&10.0&0.0912\\
# &74.4777&20.8&55.9263&631.8&1.3409&14.1421&0.0948\\
# &
# &0.2972&32.4&370.307&8.9&0.0195&1.7889&0.0109\\
# &0.8904&30.2&248.4539&53.1&0.0743&2.8284&0.0263\\
# &5.4687&29.7&226.9581&173.6&0.4261&4.0&0.1065\\
# &
# &0.657&28.7&209.8456&48.2&0.3551&1.2649&0.2807\\
# &0.8303&28.0&182.8768&54.3&0.5279&2.0&0.2639\\
# &1.8947&18.2&53.5854&119.9&0.7147&2.8284&0.2527\\
# &

# %%
#parameters for tab 3
n=50
l=10
b=np.sqrt(100)
L=20

eps=[1,0.1,0.01,0.001]
rho=1
sigma=1.2

tabs={}
for j in range(3):
    parametri={}
    for i in range(4):
        
        parametri[i]=[n,l,L,sets[j],iters,eps[i],rho,sigma,b]
    tabs[j]=tables(parametri,seed)

for j in range(3):
    print(pytolatex(np.round(tabs[j],4)))
# Out:
# &1.3526&15.8&18.4737&35.2&8.3296&63.2456&0.1317\\
# &3.0567&19.5&37.3488&71.1&1.5793&20.0&0.079\\
# &4.8201&25.1&111.1694&107.4&0.4684&6.3246&0.0741\\
# &6.2356&29.8&297.8627&124.1&0.1446&2.0&0.0723\\
# &
# &0.2182&19.9&37.8264&7.9&1.9942&17.8885&0.1115\\
# &0.2792&26.0&115.2386&9.3&0.2056&5.6569&0.0363\\
# &0.3357&32.4&370.307&10.0&0.0207&1.7889&0.0116\\
# &0.3791&38.8&1188.0654&9.9&0.0021&0.5657&0.0037\\
# &
# &0.093&5.4&3.5498&6.8&4.9354&12.6491&0.3902\\
# &0.497&15.7&32.3065&44.1&1.3591&4.0&0.3398\\
# &1.1468&25.0&160.3226&77.7&0.3045&1.2649&0.2407\\
# &1.2192&35.1&670.8251&78.4&0.0911&0.4&0.2279\\
# &

# %%
#parameters for tab 4
n=[25,50,75,100]
l=10
b=np.sqrt(100)
L=20

eps=0.01
rho=1
sigma=1.2

sets=["cubo"]
iters=100
tabs={}
for j in range(len(sets)):
    parametri={}
    for i in range(4):
        
        parametri[i]=[n[i],l,L,sets[j],iters,eps,rho,sigma,b]
    tabs[j]=tables(parametri,seed)

for j in range(len(sets)):
    print(pytolatex(np.round(tabs[j],4)))
# Out:
# &1.4866&24.34&119.6224&45.63&0.3676&4.4721&0.0822\\
# &5.8452&25.94&138.9233&94.33&0.4352&6.3246&0.0688\\
# &18.4716&25.76&141.7199&150.7&0.4146&7.746&0.0535\\
# &24.0471&25.17&119.1973&149.99&0.381&8.9443&0.0426\\
# &

# %%
#parameters for tab 5
n=50
l=10
b=np.sqrt(100)
L=20

eps=0.01
rho=[100,500,1000,2000]
sigma=1.2


tabs={}
for j in range(3):
    parametri={}
    for i in range(4):
        
        parametri[i]=[n,l,L,sets[j],iters,eps,rho[i],sigma,b]
    tabs[j]=tables(parametri,seed)

for j in range(3):
    print(pytolatex(np.round(tabs[j],4)))
# Out:
# &4.6865&0.9&120.96&104.5&0.4302&6.3246&0.068\\
# &4.9113&0.0&500.0&99.0&0.4624&6.3246&0.0731\\
# &6.2557&0.0&1000.0&108.2&0.4484&6.3246&0.0709\\
# &6.8177&0.0&2000.0&111.8&0.4698&6.3246&0.0743\\
# &
# &0.2296&7.1&367.8732&10.0&0.0207&1.7889&0.0116\\
# &0.1678&0.0&500.0&10.0&0.0207&1.7889&0.0116\\
# &0.1407&0.0&1000.0&9.9&0.0207&1.7889&0.0116\\
# &0.1323&0.0&2000.0&10.0&0.0207&1.7889&0.0116\\
# &
# &1.2912&2.8&183.9955&78.0&0.3251&1.2649&0.257\\
# &1.1956&0.0&500.0&81.7&0.3183&1.2649&0.2517\\
# &1.1807&0.0&1000.0&82.7&0.3071&1.2649&0.2428\\
# &1.0858&0.0&2000.0&78.5&0.3171&1.2649&0.2507\\
# &
