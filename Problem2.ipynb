# %%
import numpy as np
from functions_exp2 import tab6
from functions_exp2 import tab7
from functions_exp2 import time_plot

# %%
#seed=np.random.randint(100000)
seed=73348
iters=100
MAXTIME=300

# %%
#Comparison of the perfomances of Alg3/a-IRG/IR-EG on the oligopoly problem with (N,J)=(4,3)
tab6(MAXTIME,iters,seed)

# %%
##Comparison of the perfomances of Alg3/IR-EG on the oligopoly problem with (N,J)=[(4,3),(5,4),(6,5),(7,5)]
tab7(MAXTIME,iters,seed)
